# %% [markdown]
# # 1.1 Get started + import

# %%
# !pip install plotly
# !pip install scipy
# Out:
# Requirement already satisfied: plotly in c:\users\heidi\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\heidi\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: scipy in c:\users\heidi\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\heidi\anaconda3\lib\site-packages (from scipy) (1.24.3)

# %%
# Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

# Import Pandas, Numpy and Scipy
import pandas as pd
import numpy as np
from scipy.stats import norm

# Import plotly express
import plotly.express as px
import plotly.graph_objects as go
px.defaults.width, px.defaults.height = 1000, 600
# Out:
# 11

# %% [markdown]
# # 1.2 Load GBPUSD Data

# %%
# Load the CSV file
df = pd.read_csv('CQF_Jan_24_M1L1_Excel-1.csv', index_col=0, parse_dates=True)['2020':'2023']
df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-12-22  4753.919922  4772.939941  4736.770020  4754.629883  4754.629883
# 2023-12-26  4758.859863  4784.720215  4758.450195  4774.750000  4774.750000
# 2023-12-27  4773.450195  4785.390137  4768.899902  4781.580078  4781.580078
# 2023-12-28  4786.439941  4793.299805  4780.979980  4783.350098  4783.350098
# 2023-12-29  4782.879883  4788.430176  4751.990234  4769.830078  4769.830078
#
#                 Volume
# Date
# 2023-12-22  3046770000
# 2023-12-26  2513910000
# 2023-12-27  2748450000
# 2023-12-28  2698860000
# 2023-12-29  3126060000

# %%
# Visualize the plot to verify the data
px.line(df, y="Adj Close", title="SPY Historical Chart")
# Out:
# <div>                            <div id="97deae6a-9b91-4dd1-9e89-d584c552a2fd" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97deae6a-9b91-4dd1-9e89-d584c552a2fd")) {                    Plotly.newPlot(                        "97deae6a-9b91-4dd1-9e89-d584c552a2fd",                        [{"hovertemplate":"Date=%{x}<br>Adj Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T ...

# %%
# Verify the datetime format
df.index
# Out:
# DatetimeIndex(['2011-01-03', '2011-01-04', '2011-01-05', '2011-01-06',
#                '2011-01-07', '2011-01-10', '2011-01-11', '2011-01-12',
#                '2011-01-13', '2011-01-14',
#                ...
#                '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20',
#                '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27',
#                '2023-12-28', '2023-12-29'],
#               dtype='datetime64[ns]', name='Date', length=3270, freq=None)

# %%
# Get last 300 index values
df.index[-300:]

# %% [markdown]
# # 1.3 Calculate return

# %%
# Calculate returns and add it to existing DataFrame as a column
df['Return'] = df['Adj Close'].pct_change().fillna(0)

# Get first 5 rows
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3257.850098
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3234.850098
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3246.280029
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3237.179932
# 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3253.050049
#
#                 Volume    Return
# Date
# 2020-01-02  3459930000  0.000000
# 2020-01-03  3484700000 -0.007060
# 2020-01-06  3702460000  0.003533
# 2020-01-07  3435910000 -0.002803
# 2020-01-08  3726840000  0.004902

# %% [markdown]
# # 1.4 Calculate Mean, Sigma and Scaled Returns

# %%
# Calculate mean and sigma
mu = np.mean(df['Return'])
sigma = np.std(df['Return'])

# Calculate the scaled return : zscore
df['Scaled_Return'] = df['Return'].apply(lambda x: (x-mu)/sigma)

# Check the output
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3257.850098
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3234.850098
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3246.280029
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3237.179932
# 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3253.050049
#
#                 Volume    Return  Scaled_Return
# Date
# 2020-01-02  3459930000  0.000000      -0.033455
# 2020-01-03  3484700000 -0.007060      -0.520925
# 2020-01-06  3702460000  0.003533       0.210518
# 2020-01-07  3435910000 -0.002803      -0.227013
# 2020-01-08  3726840000  0.004902       0.305050

# %% [markdown]
# # 1.5 Plot Histogram

# %%
# Generate some data (replace with your scaled returns data)
data = df['Scaled_Return']
data
# Out:
# Date
# 2020-01-02   -0.033455
# 2020-01-03   -0.520925
# 2020-01-06    0.210518
# 2020-01-07   -0.227013
# 2020-01-08    0.305050
#                 ...
# 2023-12-22    0.081169
# 2023-12-26    0.258735
# 2023-12-27    0.065316
# 2023-12-28   -0.007895
# 2023-12-29   -0.228617
# Name: Scaled_Return, Length: 1006, dtype: float64

# %%
# Create the normal distribution plot
x = np.linspace(data.min(), data.max(), 200)
y = norm.pdf(x, data.mean(), data.std()) # y = (1/np.sqrt(2*np.pi) * np.exp(-0.5*x**2))

# Create the histogram
fig = px.histogram(data, x=data, histnorm='probability density', nbins=200, labels={"x":""}, title='Empirical Vs Normal Distribution')
fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Normal Distribution'))  # red line to compare with standard normal distribution

# Show the plot
fig.show()  # lots of fat tails when zooming in on the "sides"
# Out:
# <div>                            <div id="78a2332d-914a-4483-9c21-348cdc333b91" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78a2332d-914a-4483-9c21-348cdc333b91")) {                    Plotly.newPlot(                        "78a2332d-914a-4483-9c21-348cdc333b91",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":200,"offsetgroup":"","orientation":"v","showlegend":false,"x":[-0